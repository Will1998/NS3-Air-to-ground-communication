# %%
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# LOS 20dBm
y1 = [74.7384, 68.1158, 64.2418, 61.493, 59.3611, 57.6191, 56.1463, 54.8704, 53.7451, 52.7384, 51.8278, 49.871, 48.2478, 46.8607, 45.6496, 44.5749, 43.609, 40.4998, 38.1577, 36.2782, 34.7085, 33.3606, 32.1794, 31.1285, 30.1817, 29.3204, 28.5303, 27.8006, 27.1227, 26.4897, 25.8961, 25.3372, 24.8091, 24.3088, 23.8334, 23.3805, 22.9481, 22.5344, 22.1378, 21.7571, 21.3909, 21.0383, 20.6981, 20.3699]


# SNR NLOS

x = [0.2, 0.4, 0.6, 0.8, 1, 1.2, 1.4, 1.6, 1.8, 2, 2.2, 2.7, 3.2, 3.7, 4.2, 4.7, 5.2, 7.2, 9.2, 11.2, 13.2, 15.2, 17.2, 19.2, 21.2, 23.2, 25.2, 27.2, 29.2, 31.2, 33.2, 35.2, 37.2, 39.2, 41.2, 43.2, 45.2, 47.2, 49.2, 51.2, 53.2, 55.2, 57.2, 59.2]
y2 = []
def cal(a):
  y = -16.4 * math.log10(a) - 45.05 + 93.97
  return(y)
for i in x:
  y2.append(cal(i)) 
'''  
# SNR FRIIS
y3 = [42.21 , 36.19 , 32.67 , 30.17 , 28.23 , 26.65 , 25.31 , 24.15 , 23.13 , 22.21 , 21.38 , 20.63 , 19.93 , 19.29 , 18.69 , 18.13 , 17.60 , 17.11 , 16.64 , 16.19 , 15.77 
      , 15.36 , 14.98 , 14.61 , 14.25 , 13.91 , 13.58 , 13.27 , 12.96 , 12.67 , 12.38 , 12.11 , 11.84 , 11.58 , 11.33 , 11.08 , 10.85 , 10.62 , 10.39 , 10.17 , 9.96 , 9.75 
      , 9.54 , 9.34 , 9.15 , 8.96 , 8.77 , 8.59 , 8.41 , 8.23 , 8.06 , 7.89 , 7.73 , 7.56 , 7.40 , 7.25 , 7.09 , 6.94 , 6.79 , 6.65 , 6.50 , 6.36 , 6.22 , 6.09 , 5.95 , 
      5.82 , 5.69 , 5.56 , 5.43 , 5.31 , 5.19 , 5.06 , 4.94 , 4.83 , 4.71 , 4.59 , 4.48 , 4.37 , 4.26 , 4.15 , 4.04 , 3.93 , 3.83 , 3.73 , 3.62 , 3.52 , 3.42 , 3.32 , 3.22 
      , 3.13 , 3.03]
'''


fig, ax = plt.subplots()

ax.plot(x, y1, label=u"SNR - Simulated")
ax.plot(x, y2, label=u"SNR - Measured")

ax.set_title(u'SNR - Distance')
ax.set_xlabel(u'Distance (m)')
ax.set_ylabel(u'SNR (dB)')
ax.set_xlim(0, 60)
ax.set_ylim(0, 100)
ax.set_xticks(np.arange(0, 60,10))
ax.legend(loc=1)  # 1,2,3,4
ax.minorticks_on()  #
ax.tick_params(which='both', direction='in', bottom=True, top=True, left=True, right=True)  
ax.grid(color='k', alpha=0.5, linestyle='dashed', linewidth=0.5)
fig.tight_layout()
